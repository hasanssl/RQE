# %%
import os
import torch
import tensorflow as tf

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
import pickle
import gzip

split="test"
fl="90"
with gzip.open(f"./data/gzip_signbd/signbd_{fl}.{split}", 'rb') as f:
    # print(f"./data/gzip_signbd/signbd_{fl}.{split}")
    annotations_org = pickle.load(f)
    annotations_sf=[]
f.close()
no_items=len(annotations_org)
for count in range(no_items):
    # print(annotations_org[count])
    item =annotations_org[count]
    sample = {}
    sample['name'] = item['name']
    sample['signer'] = item['signer']
    sample['gloss'] = item['gloss'] 
    sample['text'] = item['text']
    sf_224=item['sign']
    sf_224.reshape(-1,224)
    sf_224[:,33:39]=0
    sample['sign'] = sf_224
    annotations_sf.append(sample)
        
        


with gzip.open(f"./data/gzip_signbd/ShoulderFreeze/signbd_{fl}.{split}", "wb") as file:
    pickle.dump(annotations_sf, file)
file.close()

# %%
# with gzip.open(f"./data/gzip_BdSLW401/ShoulderFreeze/BdSLW401_{fl}.{split}", 'rb') as f:
#     annotations_org = pickle.load(f)
    
# f.close()
# no_items=len(annotations_org)
# for count in range(no_items):
#     item =annotations_org[count]
#     sf= item['sign']
#     sf=sf.reshape(-1,224)
#     print(sf[:,11*3:12*3+2+1])

# %%
os.system("python3 -m signjoey train configs/sign.yaml")
# Out:
# 2025-01-25 14:20:16.260808: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-25 14:20:16.282491: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-25 14:20:16.282514: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-25 14:20:16.283088: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# os.system("/usr/bin/python3 -m signjoey test configs/sign.yaml")
