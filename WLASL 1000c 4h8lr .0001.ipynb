# %%
import os
import torch
import tensorflow as tf
# Out:
# 2025-01-12 18:25:50.795972: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-12 18:25:50.838158: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-12 18:25:50.838185: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-12 18:25:50.839682: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
# import pickle
# import gzip


# with gzip.open("./data/PoseHandLip448_original_WLASL_2000/WLASL_2000.train", 'rb') as f:
#     annotations_org = pickle.load(f)
# f.close()
# no_items=len(annotations_org)
# for count in range(no_items):
#     # print(annotations_org[count])
#     item =annotations_org[count]
#     sample = {}
#     sample['name'] = item['name']+"_2"
#     sample['signer'] = item['signer']
#     sample['gloss'] = item['gloss'] 
#     sample['text'] = item['text']
#     sample['sign'] = item['sign']
#     annotations_org.append(sample)
        
        


# with gzip.open("./data/PoseHandLip448_original_WLASL_2000/WLASL_2000_DUP.train", "wb") as file:
#     pickle.dump(annotations_org, file)
# file.close()

# %%
os.system("/usr/bin/python3 -m signjoey test configs/sign.yaml")
# Out:
# 2024-11-27 13:00:24.757150: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-27 13:00:24.780119: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-27 13:00:24.780143: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-27 13:00:24.781057: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
os.system("/usr/bin/python3 -m signjoey train configs/sign.yaml")
# Out:
# 2024-11-26 19:02:11.727760: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-26 19:02:11.751072: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 19:02:11.751099: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 19:02:11.752051: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# os.system("/usr/bin/python3 -m signjoey test configs/sign.yaml")
